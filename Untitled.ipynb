# %%
import pandas as pd

# %%
df=pd.read_csv('CAR DETAILS FROM CAR DEKHO.csv')

# %%
df1=pd.read_csv('Car details v3.csv')

# %%
df1.head()
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner     mileage   engine   max_power  \
# 0  Individual       Manual   First Owner   23.4 kmpl  1248 CC      74 bhp
# 1  Individual       Manual  Second Owner  21.14 kmpl  1498 CC  103.52 bhp
# 2  Individual       Manual   Third Owner   17.7 kmpl  1497 CC      78 bhp
# 3  Individual       Manual   First Owner   23.0 kmpl  1396 CC      90 bhp
# 4  Individual       Manual   First Owner   16.1 kmpl  1298 CC    88.2 bhp
#
#                      torque  seats
# 0            190Nm@ 2000rpm    5.0
# ...

# %%
df1=df1[['name','mileage','engine','max_power','torque','seats']]
df1.head()
# Out:
#                            name     mileage   engine   max_power  \
# 0        Maruti Swift Dzire VDI   23.4 kmpl  1248 CC      74 bhp
# 1  Skoda Rapid 1.5 TDI Ambition  21.14 kmpl  1498 CC  103.52 bhp
# 2      Honda City 2017-2020 EXi   17.7 kmpl  1497 CC      78 bhp
# 3     Hyundai i20 Sportz Diesel   23.0 kmpl  1396 CC      90 bhp
# 4        Maruti Swift VXI BSIII   16.1 kmpl  1298 CC    88.2 bhp
#
#                      torque  seats
# 0            190Nm@ 2000rpm    5.0
# 1       250Nm@ 1500-2500rpm    5.0
# 2     12.7@ 2,700(kgm@ rpm)    5.0
# 3  22.4 kgm at 1750-2750rpm    5.0
# 4     11.5@ 4,500(kgm@ rpm)    5.0

# %%
##check missing values
df1.isnull().sum()
# Out:
# name           0
# mileage      221
# engine       221
# max_power    215
# torque       222
# seats        221
# dtype: int64

# %%
df1['company'], df1['brand'], df1['rest'] =df1['name'].str.split(' ', 2).str
# Out:
# <ipython-input-80-b893b31449aa>:1: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   df1['company'], df1['brand'], df1['rest'] =df1['name'].str.split(' ', 2).str

# %%
df1.head()
# Out:
#                            name     mileage   engine   max_power  \
# 0        Maruti Swift Dzire VDI   23.4 kmpl  1248 CC      74 bhp
# 1  Skoda Rapid 1.5 TDI Ambition  21.14 kmpl  1498 CC  103.52 bhp
# 2      Honda City 2017-2020 EXi   17.7 kmpl  1497 CC      78 bhp
# 3     Hyundai i20 Sportz Diesel   23.0 kmpl  1396 CC      90 bhp
# 4        Maruti Swift VXI BSIII   16.1 kmpl  1298 CC    88.2 bhp
#
#                      torque  seats  company  brand              rest
# 0            190Nm@ 2000rpm    5.0   Maruti  Swift         Dzire VDI
# 1       250Nm@ 1500-2500rpm    5.0    Skoda  Rapid  1.5 TDI Ambition
# 2     12.7@ 2,700(kgm@ rpm)    5.0    Honda   City     2017-2020 EXi
# 3  22.4 kgm at 1750-2750rpm    5.0  Hyundai    i20     Sportz Diesel
# 4     11.5@ 4,500(kgm@ rpm)    5.0   Maruti  Swift         VXI BSIII

# %%
df1['mileage_kmpl'], df1['extra'] =df1['mileage'].str.split(' ', 1).str
df1['engine_cc'], df1['extra'] =df1['engine'].str.split(' ', 1).str
df1['max_power_bhp'], df1['extra'] =df1['max_power'].str.split(' ', 1).str
# Out:
# <ipython-input-82-feef4f8a4f60>:1: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   df1['mileage_kmpl'], df1['extra'] =df1['mileage'].str.split(' ', 1).str
# <ipython-input-82-feef4f8a4f60>:2: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   df1['engine_cc'], df1['extra'] =df1['engine'].str.split(' ', 1).str
# <ipython-input-82-feef4f8a4f60>:3: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   df1['max_power_bhp'], df1['extra'] =df1['max_power'].str.split(' ', 1).str

# %%
df1.head()
# Out:
#                            name     mileage   engine   max_power  \
# 0        Maruti Swift Dzire VDI   23.4 kmpl  1248 CC      74 bhp
# 1  Skoda Rapid 1.5 TDI Ambition  21.14 kmpl  1498 CC  103.52 bhp
# 2      Honda City 2017-2020 EXi   17.7 kmpl  1497 CC      78 bhp
# 3     Hyundai i20 Sportz Diesel   23.0 kmpl  1396 CC      90 bhp
# 4        Maruti Swift VXI BSIII   16.1 kmpl  1298 CC    88.2 bhp
#
#                      torque  seats  company  brand              rest  \
# 0            190Nm@ 2000rpm    5.0   Maruti  Swift         Dzire VDI
# 1       250Nm@ 1500-2500rpm    5.0    Skoda  Rapid  1.5 TDI Ambition
# 2     12.7@ 2,700(kgm@ rpm)    5.0    Honda   City     2017-2020 EXi
# 3  22.4 kgm at 1750-2750rpm    5.0  Hyundai    i20     Sportz Diesel
# 4     11.5@ 4,500(kgm@ rpm)    5.0   Maruti  Swift         VXI BSIII
#
#   mileage_kmpl extra engine_cc max_power_bhp
# 0         23.4   bhp      1248            74
# 1        21.14   bhp      1498        103.52
# ...

# %%
df1=df1[['company','brand','mileage_kmpl','engine_cc','max_power_bhp','seats']]

# %%
df1.head()
# Out:
#    company  brand mileage_kmpl engine_cc max_power_bhp  seats
# 0   Maruti  Swift         23.4      1248            74    5.0
# 1    Skoda  Rapid        21.14      1498        103.52    5.0
# 2    Honda   City         17.7      1497            78    5.0
# 3  Hyundai    i20         23.0      1396            90    5.0
# 4   Maruti  Swift         16.1      1298          88.2    5.0

# %%
df1["mileage_kmpl"] = pd.to_numeric(df1["mileage_kmpl"],errors='coerce')
df1["engine_cc"] = pd.to_numeric(df1["engine_cc"],errors='coerce')
df1["max_power_bhp"] = pd.to_numeric(df1["max_power_bhp"],errors='coerce')
df1["seats"] = pd.to_numeric(df1["seats"],errors='coerce')

# %%
df1=df1.groupby(['company','brand'], as_index=False).agg({'mileage_kmpl':'mean', 'engine_cc':'mean', 'max_power_bhp':'mean', 'seats':'median'})

# %%
df.head()
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 0             Maruti 800 AC  2007          60000      70000  Petrol
# 1  Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2      Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3    Datsun RediGO T Option  2017         250000      46000  Petrol
# 4     Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
#
#   seller_type transmission         owner
# 0  Individual       Manual   First Owner
# 1  Individual       Manual   First Owner
# 2  Individual       Manual   First Owner
# 3  Individual       Manual   First Owner
# 4  Individual       Manual  Second Owner

# %%
df['company'], df['brand'], df['rest'] =df['name'].str.split(' ', 2).str
# Out:
# <ipython-input-89-babe7af1f157>:1: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   df['company'], df['brand'], df['rest'] =df['name'].str.split(' ', 2).str

# %%
df.head()
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 0             Maruti 800 AC  2007          60000      70000  Petrol
# 1  Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2      Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3    Datsun RediGO T Option  2017         250000      46000  Petrol
# 4     Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
#
#   seller_type transmission         owner  company   brand         rest
# 0  Individual       Manual   First Owner   Maruti     800           AC
# 1  Individual       Manual   First Owner   Maruti   Wagon  R LXI Minor
# 2  Individual       Manual   First Owner  Hyundai   Verna       1.6 SX
# 3  Individual       Manual   First Owner   Datsun  RediGO     T Option
# 4  Individual       Manual  Second Owner    Honda   Amaze    VX i-DTEC

# %%
df.columns
# Out:
# Index(['name', 'year', 'selling_price', 'km_driven', 'fuel', 'seller_type',
#        'transmission', 'owner', 'company', 'brand', 'rest'],
#       dtype='object')

# %%
df=df[['company', 'brand', 'year', 'selling_price', 'km_driven', 'fuel', 'seller_type', 'transmission', 'owner']]

# %%
df.head()
# Out:
#    company   brand  year  selling_price  km_driven    fuel seller_type  \
# 0   Maruti     800  2007          60000      70000  Petrol  Individual
# 1   Maruti   Wagon  2007         135000      50000  Petrol  Individual
# 2  Hyundai   Verna  2012         600000     100000  Diesel  Individual
# 3   Datsun  RediGO  2017         250000      46000  Petrol  Individual
# 4    Honda   Amaze  2014         450000     141000  Diesel  Individual
#
#   transmission         owner
# 0       Manual   First Owner
# 1       Manual   First Owner
# 2       Manual   First Owner
# 3       Manual   First Owner
# 4       Manual  Second Owner

# %%
df1.shape
# Out:
# (210, 6)

# %%
df.shape
# Out:
# (4340, 9)

# %%
df=pd.merge(df, df1,  how='left', left_on=['company','brand'], right_on = ['company','brand'])

# %%
##check missing values
df.isnull().sum()
# Out:
# company           0
# brand             0
# year              0
# selling_price     0
# km_driven         0
# fuel              0
# seller_type       0
# transmission      0
# owner             0
# mileage_kmpl     44
# engine_cc        44
# max_power_bhp    44
# seats            44
# dtype: int64

# %%
df=df.dropna()

# %%
df.shape
# Out:
# (4296, 13)

# %%
print(df['company'].unique())
print(df['brand'].unique())
print(df['seller_type'].unique())
print(df['fuel'].unique())
print(df['transmission'].unique())
print(df['owner'].unique())
# Out:
# ['Maruti' 'Hyundai' 'Datsun' 'Honda' 'Tata' 'Chevrolet' 'Toyota' 'Jaguar'
#  'Mercedes-Benz' 'Audi' 'Skoda' 'Jeep' 'BMW' 'Mahindra' 'Ford' 'Nissan'
#  'Renault' 'Fiat' 'Volkswagen' 'Volvo' 'Land' 'Mitsubishi' 'Daewoo' 'MG'
#  'Force' 'Isuzu' 'Ambassador' 'Kia']
# ['800' 'Wagon' 'Verna' 'RediGO' 'Amaze' 'Alto' 'Xcent' 'Indigo' 'Creta'
#  'Celerio' 'Sail' 'Corolla' 'Ciaz' 'Venue' 'Enjoy' 'XF' 'New' 'Vitara'
#  'Q5' 'City' 'Tigor' 'A6' 'Superb' 'Innova' 'Compass' 'E-Class' 'i10' '3'
#  'Q7' 'Elantra' 'Scorpio' 'Santro' 'Grand' 'Swift' 'Eeco' 'i20' 'Omni'
#  'Indica' 'EON' 'Etios' 'Tavera' 'EcoSport' 'Civic' 'Rapid' 'Getz'
#  'Terrano' 'Elite' 'Brio' 'S-Class' 'XUV500' 'Duster' 'Bolero' 'Avventura'
#  'Jetta' 'A4' 'X1' 'V40' 'SX4' '7' 'Sonata' 'Micra' 'Xylo' 'KWID' 'Ertiga'
#  'Beat' 'Zen' 'Baleno' 'Nano' 'Cruze' 'Figo' 'Spark' 'Bolt' 'Quanto'
#  'Nexon' 'Vento' 'Esteem' '5' 'Linea' 'Scala' 'XUV300' 'S-Cross' 'Ameo'
# ...

# %%
##check missing values
df.isnull().sum()
# Out:
# company          0
# brand            0
# year             0
# selling_price    0
# km_driven        0
# fuel             0
# seller_type      0
# transmission     0
# owner            0
# mileage_kmpl     0
# engine_cc        0
# max_power_bhp    0
# seats            0
# dtype: int64

# %%
df.company.value_counts().to_dict()
# Out:
# {'Maruti': 1278,
#  'Hyundai': 821,
#  'Tata': 359,
#  'Mahindra': 355,
#  'Honda': 252,
#  'Ford': 238,
#  'Toyota': 206,
#  'Chevrolet': 188,
#  'Renault': 146,
#  'Volkswagen': 107,
#  'Skoda': 68,
#  'Nissan': 61,
#  'Audi': 55,
#  'BMW': 39,
#  'Datsun': 36,
#  'Fiat': 34,
#  'Mercedes-Benz': 23,
#  'Jaguar': 5,
#  'Land': 5,
#  'Mitsubishi': 4,
#  'Ambassador': 4,
#  'Volvo': 3,
#  'Jeep': 3,
#  'MG': 2,
#  'Force': 1,
#  'Daewoo': 1,
#  'Isuzu': 1,
#  'Kia': 1}

# %%
#keeping only top 4 companies marked
dict={'Maruti': 'Maruti',
 'Hyundai': 'Hyundai',
 'Tata': 'Tata',
 'Mahindra': 'Mahindra',
 'Honda': 'others',
 'Ford': 'others',
 'Toyota': 'others',
 'Chevrolet': 'others',
 'Renault': 'others',
 'Volkswagen': 'others',
 'Skoda': 'others',
 'Nissan': 'others',
 'Audi': 'others',
 'BMW': 'others',
 'Datsun': 'others',
 'Fiat': 'others',
 'Mercedes-Benz': 'others',
 'Land': 'others',
 'Jaguar': 'others',
 'Ambassador': 'others',
 'Mitsubishi': 'others',
 'Volvo': 'others',
 'Jeep': 'others',
 'MG': 'others',
 'Daewoo': 'others',
 'Isuzu': 'others',
 'Kia': 'others',
 'Force': 'others'}

# %%
df['company']=df['company'].map(dict)

# %%
df.head(10)
# Out:
#    company    brand  year  selling_price  km_driven    fuel seller_type  \
# 0   Maruti      800  2007          60000      70000  Petrol  Individual
# 1   Maruti    Wagon  2007         135000      50000  Petrol  Individual
# 2  Hyundai    Verna  2012         600000     100000  Diesel  Individual
# 3   others   RediGO  2017         250000      46000  Petrol  Individual
# 4   others    Amaze  2014         450000     141000  Diesel  Individual
# 5   Maruti     Alto  2007         140000     125000  Petrol  Individual
# 6  Hyundai    Xcent  2016         550000      25000  Petrol  Individual
# 7     Tata   Indigo  2014         240000      60000  Petrol  Individual
# 8  Hyundai    Creta  2015         850000      25000  Petrol  Individual
# 9   Maruti  Celerio  2017         365000      78000     CNG  Individual
#
#   transmission         owner  mileage_kmpl    engine_cc  max_power_bhp  seats
# 0       Manual   First Owner     16.082796   796.000000      36.989247    4.0
# ...

# %%
#dropping brand due to too many nominal categories
df=df.drop('brand', axis=1)

# %%
df.describe()
# Out:
#               year  selling_price      km_driven  mileage_kmpl    engine_cc  \
# count  4296.000000   4.296000e+03    4296.000000   4296.000000  4296.000000
# mean   2013.106378   4.893740e+05   66388.294460     19.375315  1408.586638
# std       4.170085   5.243293e+05   46568.362169      3.150440   476.032503
# min    1992.000000   2.000000e+04       1.000000      7.748000   624.000000
# 25%    2011.000000   2.049990e+05   35000.000000     17.293023  1152.110294
# 50%    2014.000000   3.500000e+05   60000.000000     19.981066  1282.160000
# 75%    2016.000000   6.000000e+05   90000.000000     21.833333  1507.500000
# max    2020.000000   8.150000e+06  806599.000000     25.883529  2993.000000
#
#        max_power_bhp        seats
# count    4296.000000  4296.000000
# mean       88.085355     5.338920
# std        31.983113     0.857825
# min        34.507692     4.000000
# 25%        66.480142     5.000000
# 50%        79.183186     5.000000
# 75%       103.482353     5.000000
# ...

# %%
df.columns
# Out:
# Index(['company', 'year', 'selling_price', 'km_driven', 'fuel', 'seller_type',
#        'transmission', 'owner', 'mileage_kmpl', 'engine_cc', 'max_power_bhp',
#        'seats'],
#       dtype='object')

# %%
final_dataset=df[['company', 'year', 'selling_price', 'km_driven', 'fuel', 'seller_type',
       'transmission', 'owner', 'mileage_kmpl', 'engine_cc', 'max_power_bhp',
       'seats']]

# %%
dictionary={'Test Drive Car':0,
            'First Owner':1,
            'Second Owner':2,
            'Third Owner':3,
            'Fourth & Above Owner':4
 }

# %%
final_dataset['owner']=final_dataset['owner'].map(dictionary)

# %%
final_dataset.head()
# Out:
#    company  year  selling_price  km_driven    fuel seller_type transmission  \
# 0   Maruti  2007          60000      70000  Petrol  Individual       Manual
# 1   Maruti  2007         135000      50000  Petrol  Individual       Manual
# 2  Hyundai  2012         600000     100000  Diesel  Individual       Manual
# 3   others  2017         250000      46000  Petrol  Individual       Manual
# 4   others  2014         450000     141000  Diesel  Individual       Manual
#
#    owner  mileage_kmpl    engine_cc  max_power_bhp  seats
# 0      1     16.082796   796.000000      36.989247    4.0
# 1      1     20.397943  1015.780142      66.480142    5.0
# 2      1     19.981066  1554.340102     118.634010    5.0
# 3      1     22.624000   895.000000      60.027200    5.0
# 4      2     22.025490  1339.558824      92.703431    5.0

# %%
final_dataset['Current Year']=2021

# %%
final_dataset['no_year']=final_dataset['Current Year']- final_dataset['year']

# %%
final_dataset.drop(['year','Current Year'],axis=1,inplace=True)

# %%
final_dataset=pd.get_dummies(final_dataset,drop_first=True)

# %%
final_dataset.corr()
# Out:
#                               selling_price  km_driven     owner  \
# selling_price                      1.000000  -0.186428 -0.235002
# km_driven                         -0.186428   1.000000  0.322181
# owner                             -0.235002   0.322181  1.000000
# mileage_kmpl                      -0.277063  -0.270612 -0.163392
# engine_cc                          0.528242   0.243344  0.015843
# max_power_bhp                      0.695110   0.077866 -0.072943
# seats                              0.193735   0.210016  0.039000
# no_year                           -0.433425   0.423383  0.466127
# company_Mahindra                   0.058266   0.111302  0.020600
# company_Maruti                    -0.182427  -0.044330  0.051389
# company_Tata                      -0.119467   0.064377  0.032565
# company_others                     0.264443   0.032382 -0.054206
# fuel_Diesel                        0.294953   0.291614  0.000336
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
#get correlations of each features in dataset
corrmat = final_dataset.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(20,20))
#plot heat map
g=sns.heatmap(final_dataset[top_corr_features].corr(),annot=True,cmap="RdYlGn")

# %%
X=final_dataset.iloc[:,1:]
y=final_dataset.iloc[:,0]

# %%
X['owner'].unique()
# Out:
# array([1, 2, 4, 3, 0], dtype=int64)

# %%
X.head()
# Out:
#    km_driven  owner  mileage_kmpl    engine_cc  max_power_bhp  seats  no_year  \
# 0      70000      1     16.082796   796.000000      36.989247    4.0       14
# 1      50000      1     20.397943  1015.780142      66.480142    5.0       14
# 2     100000      1     19.981066  1554.340102     118.634010    5.0        9
# 3      46000      1     22.624000   895.000000      60.027200    5.0        4
# 4     141000      2     22.025490  1339.558824      92.703431    5.0        7
#
#    company_Mahindra  company_Maruti  company_Tata  company_others  \
# 0                 0               1             0               0
# 1                 0               1             0               0
# 2                 0               0             0               0
# 3                 0               0             0               1
# 4                 0               0             0               1
#
#    fuel_Diesel  fuel_Electric  fuel_LPG  fuel_Petrol  seller_type_Individual  \
# ...

# %%
### Feature Importance
from sklearn.ensemble import ExtraTreesRegressor
model = ExtraTreesRegressor()
model.fit(X,y)
# Out:
# ExtraTreesRegressor()

# %%
print(model.feature_importances_)
# Out:
# [4.33421930e-02 1.40916123e-02 3.54681108e-02 1.24872625e-01
#  2.77885897e-01 2.14495408e-02 2.12020141e-01 2.28741005e-03
#  1.84884430e-03 5.35696721e-03 1.94700189e-02 2.62787811e-02
#  1.51400233e-04 1.25982893e-05 2.06104566e-03 1.08858728e-02
#  2.13443108e-03 2.00382510e-01]

# %%
#plot graph of feature importances for better visualization
#feat_importances = pd.Series(model.feature_importances_, index=X.columns)
#feat_importances.nlargest(10).plot(kind='barh')
#plt.show()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
from sklearn.ensemble import RandomForestRegressor
regressor=RandomForestRegressor()

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
#Randomized Search CV

import numpy as np

# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 100, stop = 1000, num = 10)]
# Number of features to consider at every split
max_features = ['auto', 'sqrt']
# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(5, 30, num = 6)]
# max_depth.append(None)
# Minimum number of samples required to split a node
min_samples_split = [2, 5, 10, 15, 100]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 5, 10]

# %%
# Create the random grid
random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf}

print(random_grid)
# Out:
# {'n_estimators': [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000], 'max_features': ['auto', 'sqrt'], 'max_depth': [5, 10, 15, 20, 25, 30], 'min_samples_split': [2, 5, 10, 15, 100], 'min_samples_leaf': [1, 2, 5, 10]}

# %%
# Use the random grid to search for best hyperparameters
# First create the base model to tune
rf = RandomForestRegressor()

# %%
# Random search of parameters, using 3 fold cross validation, 
# search across 100 different combinations
rf_random = RandomizedSearchCV(estimator = rf, param_distributions = random_grid,scoring='neg_mean_squared_error', n_iter = 10, cv = 5, verbose=2, random_state=42, n_jobs = 1)

# %%
rf_random.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] n_estimators=100, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=15
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  n_estimators=100, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=15, total=   0.6s
# [CV] n_estimators=100, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=15
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.5s remaining:    0.0s
# [CV]  n_estimators=100, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=15, total=   0.6s
# [CV] n_estimators=100, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=15
# [CV]  n_estimators=100, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=15, total=   0.5s
# [CV] n_estimators=100, min_samples_split=5, min_samples_leaf=2, max_features=auto, max_depth=15
# ...

# %%
rf_random.best_params_
# Out:
# {'n_estimators': 100,
#  'min_samples_split': 5,
#  'min_samples_leaf': 2,
#  'max_features': 'auto',
#  'max_depth': 15}

# %%
best_random=rf_random.best_estimator_

# %%
predictions=best_random.predict(X_test)

# %%
#sns.distplot(y_test-predictions)

# %%
#plt.scatter(y_test,predictions)

# %%
from sklearn import metrics
print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 77406.54941969045
# MSE: 39381634983.15717
# RMSE: 198448.06621168464

# %%
import pickle
# open a file, where you ant to store the data
file = open('random_forest_regression_model.pkl', 'wb')

# dump information to that file
pickle.dump(best_random, file)
